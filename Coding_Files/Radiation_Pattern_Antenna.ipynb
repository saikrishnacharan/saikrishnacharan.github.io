# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
T = 180

# %%
def vary_par(ratio,N):
    T=180
    theta = np.linspace(-90,90,T)
    pd=2*np.pi*ratio*(np.sin(np.deg2rad(theta)))
    AF=np.zeros(T)+1j*np.zeros(T)
    for j in range(T):
        for i in range(N):
            AF[j]=AF[j]+np.exp(1j*i*pd[j]);
    return AF

# %%
# AF_th=vary_par(2.5,2)
# Angles = np.linspace(-90,90,T);
# print(AF_th.shape)
# # AF_th=np.real(AF_th)
# plt.plot(Angles,10*np.log10((abs(AF_th*AF_th))/4))
# # plt.ylim([-40,0])
# # abs(AF_th[0]*AF_th[0])

# %%
pip install celluloid
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
from matplotlib.animation import PillowWriter
import numpy as np
from celluloid import Camera
# from matplotlib.animation.PillowWriter
fig = plt.figure(figsize=(8, 5))
# fig=plt.figure()
plt.xlim(-90,90)
plt.ylim(-40,1)
camera = Camera(fig)
# val=np.linspace(0.5,5,20)
val=np.arange(0.25,5,0.25)
for i in val:
    T=180
    AF_th=vary_par(i,2)
    Angles = np.linspace(-90,90,T)
    f = plt.plot(Angles,10*np.log10((abs(AF_th*AF_th))/4))
    plt.ylabel("AF(theta)")
    plt.xlabel("theta")
    plt.title("Radiation Patter by tweaking d/λ with 2 antennas")
    plt.legend(f, [f'd/λ = {i}'])
    camera.snap()
animation1 = camera.animate(interval = 1000, repeat = True,repeat_delay = 1000,blit=True)
f = r"C:\charan/Ratio_Tweak.gif" 
writergif = PillowWriter(fps=1) 
animation1.save(f, writer=writergif)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
fig = plt.figure(figsize=(8, 5))
plt.xlim(-90,90)
plt.ylim(-40,40)
camera = Camera(fig)
# val=np.linspace(0.5,5,20)
val=np.arange(1,30,1)
for i in val:
    T=180
    AF_th=vary_par(0.5,i)
    Angles = np.linspace(-90,90,T)
    f = plt.plot(Angles,10*np.log10((abs(AF_th*AF_th))/4))
    plt.ylabel("AF(theta)")
    plt.xlabel("theta")
    width=50.8/(np.pi*i*0.5)    
    plt.title("Radiation Patter by tweaking Number of Antennas width d/λ=0.5 ")
    plt.legend(f, [f'Number of antennas {i}'])
    message = f"Directive gain {max(10*np.log10((abs(AF_th*AF_th))/4))}"
    message1=f"HPBW {width}°"
    plt.text(10,30,message)
    plt.text(10,25,message1)
#     plt.legend(f, [f'Number of antennas {max(10*np.log10((abs(AF_th*AF_th))/4))}'])
    camera.snap()
animation1 = camera.animate(interval = 1000, repeat = True,repeat_delay = 1000,blit=True)
# animation.save('No_of_antennas_tweaking.gif',writer='PillowWriter', fps=30)

f = r"C:\charan/Antenna_Tweak.gif" 
writergif = PillowWriter(fps=1) 
animation1.save(f, writer=writergif)
# Out:
# <img src="data:image/png;base64,..." width="913.6">

# %%
pip install Wand

# %%
pip install ffmpeg
# Out:
# ...
#   Created wheel for ffmpeg: filename=ffmpeg-1.4-py3-none-any.whl size=6086 sha256=3edbfd681b5e006ef197ec2a76fb945afe297cc095f021009256bde68f3d41d3
#   Stored in directory: c:\users\charan\appdata\local\pip\cache\wheels\aa\0d\3c\5a9cbae53044e993a211358ddae115ce34bcbc29f7a3bd9155
# Successfully built ffmpeg
# ...
# Note: you may need to restart the kernel to use updated packages.
